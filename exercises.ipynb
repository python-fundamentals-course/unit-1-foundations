# %% [markdown]
# # Unit 1: Python Foundations & Setup — Exercises
#
# > **Python Fundamentals**
#
# Complete the reading materials, curated videos, and `notebook.ipynb` before working through these exercises.

# %% [markdown]
# ## Learning objectives
#
# By the end of this unit you will be able to:
#
# - Run Python in a Jupyter notebook inside GitHub Codespaces
# - Explain the difference between int, float, str, and bool
# - Write and run a simple script using variables and print()

# %% [markdown]
# ## Exercise 1: Variables and types
#
# Create three variables describing yourself:
#
# - `name` — your name (a `str`)
# - `age` — your age in years (an `int`)
# - `is_student` — whether you are currently studying (a `bool`)
#
# For each variable, print its value **and** its type using `type()`.

# %%
# TODO: create the three variables


# TODO: print each variable and its type, e.g.
# print(name, type(name))

# %% [markdown]
# ## Exercise 2: Arithmetic with GST
#
# A bookshop sells a textbook for **$45.00**. Singapore's GST rate is **9%** (`0.09`).
#
# 1. Calculate the GST amount on the textbook
# 2. Calculate the total price (textbook price + GST)
# 3. Print both values, formatted to 2 decimal places using an f-string

# %%
price = 45.00
gst_rate = 0.09

# TODO: calculate gst_amount

# TODO: calculate total_price

# TODO: print both values formatted to 2 decimal places

# %% [markdown]
# ## Exercise 3: String manipulation
#
# Given the string `full_name = "ada lovelace"`, write code to produce:
#
# 1. `title_name` — the name in title case (e.g. `"Ada Lovelace"`)
# 2. `initials` — the initials in uppercase, joined together (e.g. `"AL"`)
# 3. `name_length` — the number of letters in the name, **not counting the space**
#
# Print all three results.

# %%
full_name = "ada lovelace"

# TODO: title_name - use .title()

# TODO: initials - use the first letter of each word, uppercase

# TODO: name_length - use .replace() and len()

# TODO: print all three results

# %% [markdown]
# ## Exercise 4: Putting it together — a profile message
#
# Using the variables from Exercises 1-3 (`name`, `age`, `title_name`, `price`, `gst_amount`, `total_price`), print a short profile message using a single f-string, in this format:
#
# ```
# Hi, I'm Mei Lin (27). My name in title case is Mei Lin.
# My textbook costs $45.00 (GST: $4.05, total: $49.05).
# ```
#
# *Tip: f-strings can span multiple lines if you wrap them in parentheses, or you can use two `print()` calls.*

# %%
# TODO: print a profile message combining the variables above

# %% [markdown]
# ## Done?
#
# Run the tests (`pytest tests/ -v`) to check whether your answer is correct. Your solution doesn't need to match any particular approach, as long as it produces the right results — your trainer can walk through worked solutions in class.
#
# Once you have passed all the tests in Unit 1, you can progress to Unit 2 at:
#
# https://github.com/python-fundamentals-course/unit-2-control-flow
